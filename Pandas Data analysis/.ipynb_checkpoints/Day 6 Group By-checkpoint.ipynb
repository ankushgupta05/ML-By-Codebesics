# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sample data\\group_city.csv')
df
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york           32          6    Rain
# 1   02-01-2017  new york           36          7   Sunny
# 2   03-01-2017  new york           28         12    Snow
# 3   04-01-2017  new york           33         15   Sunny
# 4   05-01-2017    mumbai           90          5     Fog
# 5   06-01-2017    mumbai           85         20     Fog
# 6   07-01-2017    mumbai           87         13    Rain
# 7   08-01-2017     paris           92          8   Sunny
# 8   09-01-2017     paris           45         12  Cloudy
# 9   10-01-2017     paris           50         10  Cloudy
# 10  11-01-2017    indore           45         11    Rain

# %%
g = df.groupby('city')
g

# %%
for i in g:
    print(i)
    print()
    print()
# Out:
# ('indore',            day    city  temperature  windspeed event
# 10  11-01-2017  indore           45         11  Rain)
#
#
# ('mumbai',           day    city  temperature  windspeed event
# 4  05-01-2017  mumbai           90          5   Fog
# 5  06-01-2017  mumbai           85         20   Fog
# 6  07-01-2017  mumbai           87         13  Rain)
#
#
# ('new york',           day      city  temperature  windspeed  event
# 0  01-01-2017  new york           32          6   Rain
# 1  02-01-2017  new york           36          7  Sunny
# 2  03-01-2017  new york           28         12   Snow
# 3  04-01-2017  new york           33         15  Sunny)
#
#
# ('paris',           day   city  temperature  windspeed   event
# 7  08-01-2017  paris           92          8   Sunny
# 8  09-01-2017  paris           45         12  Cloudy
# 9  10-01-2017  paris           50         10  Cloudy)

# %%
for city,i in g:
    print('City Is : ',city)
    print(i)
    print()
    print()
# Out:
# City Is :  indore
#            day    city  temperature  windspeed event
# 10  11-01-2017  indore           45         11  Rain
#
#
# City Is :  mumbai
#           day    city  temperature  windspeed event
# 4  05-01-2017  mumbai           90          5   Fog
# 5  06-01-2017  mumbai           85         20   Fog
# 6  07-01-2017  mumbai           87         13  Rain
#
#
# City Is :  new york
#           day      city  temperature  windspeed  event
# 0  01-01-2017  new york           32          6   Rain
# 1  02-01-2017  new york           36          7  Sunny
# 2  03-01-2017  new york           28         12   Snow
# 3  04-01-2017  new york           33         15  Sunny
#
#
# City Is :  paris
#           day   city  temperature  windspeed   event
# 7  08-01-2017  paris           92          8   Sunny
# 8  09-01-2017  paris           45         12  Cloudy
# 9  10-01-2017  paris           50         10  Cloudy

# %%
g.get_group('mumbai')
# Out:
#           day    city  temperature  windspeed event
# 4  05-01-2017  mumbai           90          5   Fog
# 5  06-01-2017  mumbai           85         20   Fog
# 6  07-01-2017  mumbai           87         13  Rain

# %%
g.get_group('new york')
# Out:
#           day      city  temperature  windspeed  event
# 0  01-01-2017  new york           32          6   Rain
# 1  02-01-2017  new york           36          7  Sunny
# 2  03-01-2017  new york           28         12   Snow
# 3  04-01-2017  new york           33         15  Sunny

# %%
g.max()
# Out:
#                  day  temperature  windspeed  event
# city
# indore    11-01-2017           45         11   Rain
# mumbai    07-01-2017           90         20   Rain
# new york  04-01-2017           36         15  Sunny
# paris     10-01-2017           92         12  Sunny

# %%
g.min()
# Out:
#                  day  temperature  windspeed   event
# city
# indore    11-01-2017           45         11    Rain
# mumbai    05-01-2017           85          5     Fog
# new york  01-01-2017           28          6    Rain
# paris     08-01-2017           45          8  Cloudy

# %%
g.mean()
# Out:
# C:\Users\Ankush Gupta\AppData\Local\Temp\ipykernel_13572\2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#           temperature  windspeed
# city
# indore      45.000000  11.000000
# mumbai      87.333333  12.666667
# new york    32.250000  10.000000
# paris       62.333333  10.000000

# %%
g.describe()
# Out:
#          temperature                                                       \
#                count       mean        std   min   25%   50%    75%   max
# city
# indore           1.0  45.000000        NaN  45.0  45.0  45.0  45.00  45.0
# mumbai           3.0  87.333333   2.516611  85.0  86.0  87.0  88.50  90.0
# new york         4.0  32.250000   3.304038  28.0  31.0  32.5  33.75  36.0
# paris            3.0  62.333333  25.813433  45.0  47.5  50.0  71.00  92.0
#
#          windspeed
#              count       mean       std   min    25%   50%    75%   max
# city
# indore         1.0  11.000000       NaN  11.0  11.00  11.0  11.00  11.0
# mumbai         3.0  12.666667  7.505553   5.0   9.00  13.0  16.50  20.0
# new york       4.0  10.000000  4.242641   6.0   6.75   9.5  12.75  15.0
# paris          3.0  10.000000  2.000000   8.0   9.00  10.0  11.00  12.0

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# indore      Axes(0.125,0.11;0.775x0.77)
# mumbai      Axes(0.125,0.11;0.775x0.77)
# new york    Axes(0.125,0.11;0.775x0.77)
# paris       Axes(0.125,0.11;0.775x0.77)
# dtype: object
