# %%
import pandas as pd

# %%
df = pd.read_csv('sample data\\weather.csv')
df
# Out:
#          day  temperature  windspeed  event
# 0  1//1/2017         32.0        6.0   Rain
# 1  1//1/2018         35.0        7.0  Sunny
# 2  1//1/2019         28.0        2.0   Snow
# 3  1//1/2020          NaN        NaN    NaN

# %%
df1 = pd.read_csv('sample data\\weather.csv',skiprows= 1)
df1
# Out:
#    1//1/2017    32    6   Rain
# 0  1//1/2018  35.0  7.0  Sunny
# 1  1//1/2019  28.0  2.0   Snow
# 2  1//1/2020   NaN  NaN    NaN

# %%
df1 = pd.read_csv('sample data\\weather.csv',header= 1)
df1
# Out:
#    1//1/2017    32    6   Rain
# 0  1//1/2018  35.0  7.0  Sunny
# 1  1//1/2019  28.0  2.0   Snow
# 2  1//1/2020   NaN  NaN    NaN

# %%
df1 = pd.read_csv('sample data\\weather.csv',header= None)
df1
# Out:
#            0            1          2      3
# 0        day  temperature  windspeed  event
# 1  1//1/2017           32          6   Rain
# 2  1//1/2018           35          7  Sunny
# 3  1//1/2019           28          2   Snow
# 4  1//1/2020          NaN        NaN    NaN

# %%
df1 = pd.read_csv('sample data\\weather.csv',header= None, names=['day1','temp1','wind1','event1'])
df1 

// names use when file read and columns use when dataframe created
# Out:
#         day1        temp1      wind1 event1
# 0        day  temperature  windspeed  event
# 1  1//1/2017           32          6   Rain
# 2  1//1/2018           35          7  Sunny
# 3  1//1/2019           28          2   Snow
# 4  1//1/2020          NaN        NaN    NaN

# %%
df = pd.read_csv('sample data\\weather.csv')
df
# Out:
#          day  temperature  windspeed  event
# 0  1//1/2017         32.0        6.0   Rain
# 1  1//1/2018         35.0        7.0  Sunny
# 2  1//1/2019         28.0        2.0   Snow
# 3  1//1/2020          NaN        NaN    NaN

# %%
df = pd.read_csv('sample data\\weather.csv',nrows=3)
df
# Out:
#          day  temperature  windspeed  event
# 0  1//1/2017           32          6   Rain
# 1  1//1/2018           35          7  Sunny
# 2  1//1/2019           28          2   Snow

# %%
df = pd.read_csv('sample data\\weather.csv')
df
# Out:
#          day  temperature  windspeed  event
# 0  1//1/2017         32.0        6.0   Rain
# 1  1//1/2018         35.0        7.0  Sunny
# 2  1//1/2019         28.0        2.0   Snow
# 3  1//1/2020          NaN        NaN    NaN

# %%
df = pd.read_csv('sample data\\weather.csv',na_values=['not available','Rain'])     # it changes value in NaN
df
# Out:
#          day  temperature  windspeed  event
# 0  1//1/2017         32.0        6.0    NaN
# 1  1//1/2018         35.0        7.0  Sunny
# 2  1//1/2019         28.0        2.0   Snow
# 3  1//1/2020          NaN        NaN    NaN

# %%
df = pd.read_csv('sample data\\weather.csv',na_values=['not available','Sunny','32'])     # it changes value in NaN
df
# Out:
#          day  temperature  windspeed event
# 0  1//1/2017          NaN        6.0  Rain
# 1  1//1/2018         35.0        7.0   NaN
# 2  1//1/2019         28.0        2.0  Snow
# 3  1//1/2020          NaN        NaN   NaN

# %%
df = pd.read_csv('sample data\\weather.csv',na_values={
    'day':['not available','Sunny','32'],
    'temperature':['not available',28],
    'windspeed':[6]

})     # it changes value in NaN
df
# Out:
#          day  temperature  windspeed  event
# 0  1//1/2017         32.0        NaN   Rain
# 1  1//1/2018         35.0        7.0  Sunny
# 2  1//1/2019          NaN        2.0   Snow
# 3  1//1/2020          NaN        NaN    NaN

# %%
df.to_csv('new.csv',index=False)

# %%
df.to_csv('new2.csv')

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.to_csv('new.csv',columns=['temperature','windspeed'])  # only 2 columns store in new.csv

# %% [markdown]
# # Read excel file

# %%
df = pd.read_excel('sample data\\weather.xlsx')
df
# Out:
#          day  temperature  windspeed  event
# 0  1//1/2017         32.0        6.0   Rain
# 1  1//1/2018         35.0        7.0  Sunny
# 2  1//1/2019         28.0        2.0   Snow
# 3  1//1/2020          NaN        NaN    NaN

# %%
df = pd.read_excel('sample data\\weather.xlsx','Sheet1')
df
# Out:
#          day  temperature  windspeed  event
# 0  1//1/2017         32.0        6.0   Rain
# 1  1//1/2018         35.0        7.0  Sunny
# 2  1//1/2019         28.0        2.0   Snow
# 3  1//1/2020          NaN        NaN    NaN

# %%
def converting1(cell):
    if cell == 'Rain':
        return 'ankush'
    return cell


def converting2(cell):
    if cell == 7:   # note in  csv file 7 count as a string and here count as a interger 
        return 'gupta'
    return cell


df = pd.read_excel('sample data\\weather.xlsx','Sheet1',converters={
    'event':converting,
    'windspeed':converting2
})

df


# in csv file NaN not count means not show in table list
# Out:
#          day  temperature windspeed   event
# 0  1//1/2017         32.0         6  ankush
# 1  1//1/2018         35.0     gupta   Sunny
# 2  1//1/2019         28.0         2    Snow
# 3  1//1/2020          NaN       NaN     NaN

# %%
df.to_excel('newxl.xlsx', sheet_name='stocks') # exel file with sheet name stocks

# %%
df.to_excel('newxl.xlsx', sheet_name='stocks',index=False) # exel file with sheet name stocks

# %%
df.to_excel('newxl2.xlsx', sheet_name='stocks',startrow=2,startcol=3) # exel file with sheet name stocks

# %% [markdown]
# # create many sheet in excel file

# %%
df_ankush = pd.DataFrame({
    'shyam':['s','y','a','m'],
    'aman':['a','m','a','n'],
    'monu':['m','o','n','u']
})


df_gupta = pd.DataFrame({
    'sahu1':['s','a','h','u'],
    'sahu2':['s','a','h','u'],
    'kushwa':['k','s','w','h']
})

# %%
print(df_ankush)
print()
print(df_gupta)
# Out:
#   shyam aman monu
# 0     s    a    m
# 1     y    m    o
# 2     a    a    n
# 3     m    n    u
#
#   sahu1 sahu2 kushwa
# 0     s     s      k
# 1     a     a      s
# 2     h     h      w
# 3     u     u      h

# %%
with pd.ExcelWriter('friends.xlsx') as writer:
    df_ankush.to_excel(writer,sheet_name='ankush')
    df_gupta.to_excel(writer,sheet_name='gupta')
